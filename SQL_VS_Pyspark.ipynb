# %% [markdown]
# #See results of SQL_VS_Pyspark with out execution from
# https://k-lakshmikanth.github.io/Learn/SQL_VS_Pyspark.html

# %%
from pyspark import SparkFiles
spark.sparkContext.addFile('https://raw.githubusercontent.com/k-lakshmikanth/Databricks/main/emp.csv')
url = "file://"+SparkFiles.get("emp.csv")
df = spark.read.format("csv").option("inferSchema",True).option("header",'True').load(url)

# %%
#SELECT * FROM TABLE
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT COUNT(*) FROM  TABLE
df.count()
# Out:
# Out[4]: 14

# %%
#DESCRIBE TABLE
df.printSchema()
# Out:
# root
#  |-- empno: integer (nullable = true)
#  |-- ename: string (nullable = true)
#  |-- job: string (nullable = true)
#  |-- mgr: double (nullable = true)
#  |-- hiredate: string (nullable = true)
#  |-- sal: integer (nullable = true)
#  |-- comm: double (nullable = true)
#  |-- deptno: integer (nullable = true)

# %%
#SELECT COLUMN1,COLUMN2 FROM TABLE
df.select(['empno','ename']).display()
#               | OR | 
df.select('empno','ename').display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td></tr><tr><td>7499</td><td>ALLEN</td></tr><tr><td>7521</td><td>WARD</td></tr><tr><td>7566</td><td>JONES</td></tr><tr><td>7698</td><td>BLAKE</td></tr><tr><td>7782</td><td>CLARK</td></tr><tr><td>7788</td><td>SCOTT</td></tr><tr><td>7839</td><td>KING</td></tr><tr><td>7844</td><td>TURNER</td></tr><tr><td>7876</td><td>ADAMS</td></tr><tr><td>7900</td><td>JAMES</td></tr><tr><td>7934</td><td>MILLER</td></tr><tr><td>7902</td><td>FORD</td></tr><tr><td>7654</td><td>MARTIN</td></tr></tbody></table></div>
# <style scoped>
# ...

# %%
#SELECT * FROM TABLE WHERE COLUMN=NUMBER
display(df.filter('empno = 7369 '))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7369</td><td>SMITH</td><td>CLERK</td><td>7902.0</td><td>13-06-1993</td><td>800</td><td>null</td><td>20</td></tr></tbody></table></div>

# %%
#SELECT *FROM TABLE WHERE COLUMN=STRING
display(df.filter('job = "MANAGER"'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839.0</td><td>31-10-1995</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7698</td><td>BLAKE</td><td>MANAGER</td><td>7839.0</td><td>11-06-1992</td><td>2850</td><td>null</td><td>30</td></tr><tr><td>7782</td><td>CLARK</td><td>MANAGER</td><td>7839.0</td><td>14-05-1993</td><td>2450</td><td>null</td><td>10</td></tr></tbody></table></div>

# %%
#SELECT *FROM TABLE WHERE COLUMN IN (NUMBERS)
display(df.filter('empno in (7369,7499,7566,7698)'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN IN (STRINGS)
display(df.filter('ename in ("JAMES","MILLER","FORD","MARTIN")'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN <> NUMBER
display(df.filter('mgr <> 7698'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN NOT IN (NUMBER)
display(df.filter('mgr not in (7698,7566,7902)'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN NOT IN (STRING)
display(df.filter('ename not in ("JAMES","MILLER","FORD","MARTIN")'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN LIKE '%XYZ'
display(df.filter('ename LIKE "%S" '))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7566</td><td>JONES</td><td>MANAGER</td><td>7839.0</td><td>31-10-1995</td><td>2975</td><td>null</td><td>20</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788.0</td><td>04-06-1999</td><td>1100</td><td>null</td><td>20</td></tr><tr><td>7900</td><td>JAMES</td><td>CLERK</td><td>7698.0</td><td>23-06-2000</td><td>950</td><td>null</td><td>30</td></tr></tbody></table></div>

# %%
#SELECT *FROM TABLE WHERE COLUMN LIKE 'XYZ%'
display(df.filter('ename LIKE "A%" '))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7499</td><td>ALLEN</td><td>SALESMAN</td><td>7698.0</td><td>15-08-1998</td><td>1600</td><td>300.0</td><td>30</td></tr><tr><td>7876</td><td>ADAMS</td><td>CLERK</td><td>7788.0</td><td>04-06-1999</td><td>1100</td><td>null</td><td>20</td></tr></tbody></table></div>

# %%
#SELECT *FROM TABLE WHERE COLUMN LIKE '%XYZ%'
display(df.filter('ename LIKE "%A%" '))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN IS NULL
display(df.filter('comm is null'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT *FROM TABLE WHERE COLUMN IS NOT NULL
display(df.filter('comm is not null'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#SELECT * FROM TABLE WHERE COLUMN1 = NUMBER AND COLUMN2 = NUMBER 
display(df.filter('deptno = 30 and sal = 1500 '))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698.0</td><td>04-06-1995</td><td>1500</td><td>0.0</td><td>30</td></tr></tbody></table></div>

# %%
#SELECT * FROM TABLE WHERE COLUMN1 = STRING AND COLUMN2 = STRING 
display(df.filter('job = "SALESMAN" and sal = 1500'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empno</th><th>ename</th><th>job</th><th>mgr</th><th>hiredate</th><th>sal</th><th>comm</th><th>deptno</th></tr></thead><tbody><tr><td>7844</td><td>TURNER</td><td>SALESMAN</td><td>7698.0</td><td>04-06-1995</td><td>1500</td><td>0.0</td><td>30</td></tr></tbody></table></div>

# %%
#SELECT LENGTH(COLUMN) FROM TABLE
from pyspark.sql.functions import length,col
#display(df.select(COLUMN).withColumn('Alias',length(col(COLUMN))))
display(df.select('ename').withColumn('length of ename',length(col('ename'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>length of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>5</td></tr><tr><td>ALLEN</td><td>5</td></tr><tr><td>WARD</td><td>4</td></tr><tr><td>JONES</td><td>5</td></tr><tr><td>BLAKE</td><td>5</td></tr><tr><td>CLARK</td><td>5</td></tr><tr><td>SCOTT</td><td>5</td></tr><tr><td>KING</td><td>4</td></tr><tr><td>TURNER</td><td>6</td></tr><tr><td>ADAMS</td><td>5</td></tr><tr><td>JAMES</td><td>5</td></tr><tr><td>MILLER</td><td>6</td></tr><tr><td>FORD</td><td>4</td></tr><tr><td>MARTIN</td><td>6</td></tr></tbody></table></div>

# %%
#SELECT UPPER(COLUMN) FROM TABLE
from pyspark.sql.functions import upper
#display(df.select(COLUMN).withColumn('Alias',upper(col(COLUMN))))
display(df.select('ename').withColumn('upper of ename',upper(col('ename'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>upper of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>SMITH</td></tr><tr><td>ALLEN</td><td>ALLEN</td></tr><tr><td>WARD</td><td>WARD</td></tr><tr><td>JONES</td><td>JONES</td></tr><tr><td>BLAKE</td><td>BLAKE</td></tr><tr><td>CLARK</td><td>CLARK</td></tr><tr><td>SCOTT</td><td>SCOTT</td></tr><tr><td>KING</td><td>KING</td></tr><tr><td>TURNER</td><td>TURNER</td></tr><tr><td>ADAMS</td><td>ADAMS</td></tr><tr><td>JAMES</td><td>JAMES</td></tr><tr><td>MILLER</td><td>MILLER</td></tr><tr><td>FORD</td><td>FORD</td></tr><tr><td>MARTIN</td><td>MARTIN</td></tr></tbody></table></div>

# %%
#SELECT LOWER(COLUMN) FROM TABLE
from pyspark.sql.functions import lower
#display(df.select(COLUMN).withColumn('Alias',lower(col(COLUMN))))
display(df.select('ename').withColumn('lower of ename',lower(col("ename"))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>lower of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>smith</td></tr><tr><td>ALLEN</td><td>allen</td></tr><tr><td>WARD</td><td>ward</td></tr><tr><td>JONES</td><td>jones</td></tr><tr><td>BLAKE</td><td>blake</td></tr><tr><td>CLARK</td><td>clark</td></tr><tr><td>SCOTT</td><td>scott</td></tr><tr><td>KING</td><td>king</td></tr><tr><td>TURNER</td><td>turner</td></tr><tr><td>ADAMS</td><td>adams</td></tr><tr><td>JAMES</td><td>james</td></tr><tr><td>MILLER</td><td>miller</td></tr><tr><td>FORD</td><td>ford</td></tr><tr><td>MARTIN</td><td>martin</td></tr></tbody></table></div>

# %%
#TRIM
from pyspark.sql.functions import trim
#display(df.select(COLUMN).withColumn('Alias',trim(col(COLUMN))))
display(df.select('ename').withColumn('trim of ename',trim(col('ename'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>trim of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>SMITH</td></tr><tr><td>ALLEN</td><td>ALLEN</td></tr><tr><td>WARD</td><td>WARD</td></tr><tr><td>JONES</td><td>JONES</td></tr><tr><td>BLAKE</td><td>BLAKE</td></tr><tr><td>CLARK</td><td>CLARK</td></tr><tr><td>SCOTT</td><td>SCOTT</td></tr><tr><td>KING</td><td>KING</td></tr><tr><td>TURNER</td><td>TURNER</td></tr><tr><td>ADAMS</td><td>ADAMS</td></tr><tr><td>JAMES</td><td>JAMES</td></tr><tr><td>MILLER</td><td>MILLER</td></tr><tr><td>FORD</td><td>FORD</td></tr><tr><td>MARTIN</td><td>MARTIN</td></tr></tbody></table></div>

# %%
#LTRIM
from pyspark.sql.functions import ltrim
#display(df.select(COLUMN).withColumn('Alias',ltrim(col(COLUMN))))
display(df.select('ename').withColumn('ltrim of ename',ltrim(col('ename'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>ltrim of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>SMITH</td></tr><tr><td>ALLEN</td><td>ALLEN</td></tr><tr><td>WARD</td><td>WARD</td></tr><tr><td>JONES</td><td>JONES</td></tr><tr><td>BLAKE</td><td>BLAKE</td></tr><tr><td>CLARK</td><td>CLARK</td></tr><tr><td>SCOTT</td><td>SCOTT</td></tr><tr><td>KING</td><td>KING</td></tr><tr><td>TURNER</td><td>TURNER</td></tr><tr><td>ADAMS</td><td>ADAMS</td></tr><tr><td>JAMES</td><td>JAMES</td></tr><tr><td>MILLER</td><td>MILLER</td></tr><tr><td>FORD</td><td>FORD</td></tr><tr><td>MARTIN</td><td>MARTIN</td></tr></tbody></table></div>

# %%
#RTRIM
from pyspark.sql.functions import rtrim
#display(df.select(COLUMN).withColumn('Alias',rtrim(col(COLUMN))))
display(df.select('ename').withColumn('rtrim of ename',rtrim(col('ename'))))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ename</th><th>rtrim of ename</th></tr></thead><tbody><tr><td>SMITH</td><td>SMITH</td></tr><tr><td>ALLEN</td><td>ALLEN</td></tr><tr><td>WARD</td><td>WARD</td></tr><tr><td>JONES</td><td>JONES</td></tr><tr><td>BLAKE</td><td>BLAKE</td></tr><tr><td>CLARK</td><td>CLARK</td></tr><tr><td>SCOTT</td><td>SCOTT</td></tr><tr><td>KING</td><td>KING</td></tr><tr><td>TURNER</td><td>TURNER</td></tr><tr><td>ADAMS</td><td>ADAMS</td></tr><tr><td>JAMES</td><td>JAMES</td></tr><tr><td>MILLER</td><td>MILLER</td></tr><tr><td>FORD</td><td>FORD</td></tr><tr><td>MARTIN</td><td>MARTIN</td></tr></tbody></table></div>

# %%
#SELECT COLUMN1,SUM(COLUMN2) FROM TABLE GROUP BY COLUMN1
#display(df.select(COLUMN1,COLUMN2).groupby(COLUMN1).sum(COLUMN2))
display(df.select('deptno','sal').groupby('deptno').sum('sal'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>sum(sal)</th></tr></thead><tbody><tr><td>20</td><td>10875</td></tr><tr><td>10</td><td>8750</td></tr><tr><td>30</td><td>9400</td></tr></tbody></table></div>

# %%
#SELECT COLUMN1,SUM(COLUMN2) FROM TABLE GROUP BY COLUMN1 HAVING SUM(COLUMN2)>100
display(df.select('deptno','sal').groupby('deptno').sum('sal').where(col("SUM(sal)")>=9400))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>deptno</th><th>sum(sal)</th></tr></thead><tbody><tr><td>20</td><td>10875</td></tr><tr><td>30</td><td>9400</td></tr></tbody></table></div>

# %%
#Select job,len(job) as count from <Tablename> order by len(job) desc
from pyspark.sql.functions import length
df.select("job").withColumn("count",length(df['job'])).orderBy(length(df['job']).desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>job</th><th>count</th></tr></thead><tbody><tr><td>PRESIDENT</td><td>9</td></tr><tr><td>SALESMAN</td><td>8</td></tr><tr><td>SALESMAN</td><td>8</td></tr><tr><td>SALESMAN</td><td>8</td></tr><tr><td>SALESMAN</td><td>8</td></tr><tr><td>MANAGER</td><td>7</td></tr><tr><td>ANALYST</td><td>7</td></tr><tr><td>MANAGER</td><td>7</td></tr><tr><td>ANALYST</td><td>7</td></tr><tr><td>MANAGER</td><td>7</td></tr><tr><td>CLERK</td><td>5</td></tr><tr><td>CLERK</td><td>5</td></tr><tr><td>CLERK</td><td>5</td></tr><tr><td>CLERK</td><td>5</td></tr></tbody></table></div>
